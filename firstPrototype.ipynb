# %%
from n_module import NModule
from googleSearch import googleSearch

# %%
nlp = NModule()
gs = googleSearch()

# %%
sentence = "I see a bird and a dog flying"
#sentence2 = "There's a flamingo dancing on the roof of the big house."
#sentence_lst = [sentence,sentence2]
gs.searchObj("patates")
obj_list = nlp.extract_objects(nlp.pos_tagging(sentence))
for obj in obj_lst:
    gs.searchObj(obj)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-3-ad20c4a87d46> in <module>
#       3 #sentence_lst = [sentence,sentence2]
#       4 gs.searchObj("patates")
# ----> 5 obj_list = nlp.extract_objects(nlp.pos_tagging(sentence))
#       6 for obj in obj_lst:
#       7     gs.searchObj(obj)
#
# ~/Desktop/comp491/COMP491_Senior_Project/n_module.py in pos_tagging(self, sentence)
#      16     def pos_tagging(self, sentence):
#      17         splitted = self.split_sentence(sentence)
# ---> 18         return nltk.pos_tag(self, splitted)
#      19
#      20     # Returns a list of nouns (NN) in a pos-tagged sentence
#
# ~/anaconda3/envs/comp491/lib/python3.7/site-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     159     :rtype: list(tuple(str, str))
#     160     """
# --> 161     tagger = _get_tagger(lang)
#     162     return _pos_tag(tokens, tagset, tagger, lang)
#     163
#
# ~/anaconda3/envs/comp491/lib/python3.7/site-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     105         tagger.load(ap_russian_model_loc)
#     106     else:
# --> 107         tagger = PerceptronTagger()
#     108     return tagger
#     109
#
# ~/anaconda3/envs/comp491/lib/python3.7/site-packages/nltk/tag/perceptron.py in __init__(self, load)
#     160         if load:
#     161             AP_MODEL_LOC = 'file:' + str(
# --> 162                 find('taggers/averaged_perceptron_tagger/' + PICKLE)
#     163             )
#     164             self.load(AP_MODEL_LOC)
#
# ~/anaconda3/envs/comp491/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     699     sep = '*' * 70
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#     703
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger/averaged_perceptron_tagger.pickle
#
#   Searched in:
#     - '/Users/apple/nltk_data'
#     - '/Users/apple/anaconda3/envs/comp491/nltk_data'
#     - '/Users/apple/anaconda3/envs/comp491/share/nltk_data'
#     - '/Users/apple/anaconda3/envs/comp491/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
pos_tagged_sentence = pos_tagging(sentence)
generate_pos_dict(pos_tagged_sentence)
